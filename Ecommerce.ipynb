# %% [markdown]
# <a href="https://colab.research.google.com/github/vamshi437/ecommerce-analytics/blob/main/Ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("Book1.xlsx")
print(df)
# Out:
#     APPL-00000001 2022-01-03 00:00:00  2022  Q1   January  Argentina  \
# 0   APPL-00000002          2022-01-04  2022  Q1   January  Argentina
# 1   APPL-00000003          2022-05-18  2022  Q2       May  Argentina
# 2   APPL-00000004          2022-05-23  2022  Q2       May  Argentina
# 3   APPL-00000005          2022-07-13  2022  Q3      July  Argentina
# 4   APPL-00000006          2022-07-31  2022  Q3      July  Argentina
# ..            ...                 ...   ...  ..       ...        ...
# 93  APPL-00000095          2024-12-23  2024  Q4  December  Argentina
# 94  APPL-00000096          2024-12-27  2024  Q4  December  Argentina
# 95  APPL-00000097          2022-01-18  2022  Q1   January  Argentina
# 96  APPL-00000098          2022-03-17  2022  Q1     March  Argentina
# 97  APPL-00000099          2022-05-24  2022  Q2       May  Argentina
#
#     South America   Buenos Aires         AirPods (3rd Gen)      AirPods  ...  \
# ...

# %%
# !pwd
print(df.isnull().sum())
# Out:
# /content
# APPL-00000001            0
# 2022-01-03 00:00:00      0
# 2022                     0
# Q1                       0
# January                  0
# Argentina                0
# South America            0
# Buenos Aires             0
# AirPods (3rd Gen)        0
# AirPods                  0
# N/A                     43
# Starlight                0
# 159.27                   0
# 7                        0
# 1                        0
# 148.12                   0
# 148.12.1                 0
# ARS                      0
# 907                      0
# 134344.84                0
# Third-Party Retailer     0
# Cash                     0
# Government               0
# N/A.1                   71
# 4.1                     30
# Kept                     0
# 45                       0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# APPL-00000001                   object
# 2022-01-03 00:00:00     datetime64[ns]
# 2022                             int64
# Q1                              object
# January                         object
# Argentina                       object
# South America                   object
# Buenos Aires                    object
# AirPods (3rd Gen)               object
# AirPods                         object
# N/A                             object
# Starlight                       object
# 159.27                         float64
# 7                                int64
# 1                                int64
# 148.12                         float64
# 148.12.1                       float64
# ARS                             object
# 907                              int64
# 134344.84                      float64
# Third-Party Retailer            object
# Cash                            object
# Government                      object
# N/A.1                           object
# ...

# %% [markdown]
# ### 1. Initialize a Git Repository
# This command initializes a new Git repository in your current Colab working directory. You must run this first.

# %%
# !ls
# Out:
# Book1.xlsx  drive  Ecommerce.ipynb  sample_data

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %% [markdown]
# ### 2. Configure Git User Information
# Even if you've done this before, it's good practice to ensure your Git identity is set for this session. Replace `"Your Name"` and `"your_email@example.com"` with your actual GitHub username and email.

# %%
# !git config --global user.name "vamshi437"
# !git config --global user.email "kothapallivamshi72@gmail.com"

# %% [markdown]
# ### 3. Add Your Notebook to the Repository
# Your notebook file is `Ecommerce.ipynb`. This command adds it to the Git staging area.

# %%
import os

# Get the actual notebook filename
notebook_name = "Ecommerce.ipynb"

# Check if the notebook file exists
if not os.path.exists(notebook_name):
    print(f"Warning: The notebook '{notebook_name}' was not found in the current directory. Please ensure your notebook is saved and you're using the correct filename.")
    print("You can also run `!ls -a` to see all files and directories.")
else:
    # !git add "{notebook_name}"
    print(f"Added '{notebook_name}' to the staging area.")
# Out:
# Added 'Ecommerce.ipynb' to the staging area.

# %% [markdown]
# ### Mount Google Drive
#
# Run the following cell to mount your Google Drive. You will be prompted to grant Colab access to your Drive files. Once mounted, you can access your Drive content under `/content/drive/MyDrive/`.

# %%
from google.colab import drive
drive.mount('/content/drive')

# After mounting, you can either:
# 1. Change the current directory to where your notebook is:
#    %cd /content/drive/MyDrive/path/to/your/notebook_folder
#    (Replace 'path/to/your/notebook_folder' with the actual path in your Drive)
#
# 2. Or, copy your notebook to the current Colab directory (`/content/`):
#    !cp '/content/drive/MyDrive/path/to/your/notebook_folder/Ecommerce.ipynb' '/content/'
#    (Replace 'path/to/your/notebook_folder' with the actual path in your Drive)
#
# Choose one of the above methods. If you change directory, subsequent `!git` commands will operate in that directory.
# If you copy, then `!git add "Ecommerce.ipynb"` will work as is.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Copy 'Ecommerce.ipynb' from Google Drive to Colab's local environment
#
# **IMPORTANT:** Replace `/path/to/your/notebook_folder/` with the actual path to your `Ecommerce.ipynb` file within your Google Drive. For example, if it's directly in 'MyDrive', the path would be `'/content/drive/MyDrive/Ecommerce.ipynb'`.

# %%
# Replace 'path/to/your/notebook_folder/' with the actual path in your Drive
# !cp '/content/drive/MyDrive/path/to/your/notebook_folder/Ecommerce.ipynb' '/content/'

print("Attempted to copy Ecommerce.ipynb. Please check if the path was correct.")
# !ls # Verify if Ecommerce.ipynb is now in /content/
# Out:
# cp: cannot stat '/content/drive/MyDrive/path/to/your/notebook_folder/Ecommerce.ipynb': No such file or directory
# Attempted to copy Ecommerce.ipynb. Please check if the path was correct.
# Book1.xlsx  drive  Ecommerce.ipynb  sample_data

# %% [markdown]
# ### Find your 'Ecommerce.ipynb' file in Google Drive
#
# Run the command below to list the contents of your Google Drive's root directory (`/content/drive/MyDrive/`). Look for `Ecommerce.ipynb` or the folder it might be in. Once found, update the `!cp` command with the correct, full path.

# %% [markdown]
# Once your notebook file is accessible in the current working directory, you can re-run the `!git add` command. Don't forget to update the remote URL as well!

# %%
# Corrected: Copy 'Ecommerce.ipynb' from its likely location in Google Drive to the current Colab directory
# !cp '/content/drive/MyDrive/Colab Notebooks/Ecommerce.ipynb' '/content/'

print("Attempted to copy Ecommerce.ipynb. Please verify that it is now in the current directory.")
# !ls # Verify if Ecommerce.ipynb is now in /content/
# Out:
# Attempted to copy Ecommerce.ipynb. Please verify that it is now in the current directory.
# Book1.xlsx  drive  Ecommerce.ipynb  sample_data

# %% [markdown]
# Once you confirm `Ecommerce.ipynb` is in `/content/` (by checking the output of the `!ls` command above), you need to re-run the `!git add` command to stage your notebook for the commit. Then, you need to add your GitHub repository as a remote. **Remember to replace `<YOUR_GITHUB_REPOSITORY_URL>` with your actual GitHub repository URL.**

# %%
# Re-run the git add command after the notebook is copied
import os
notebook_name = "Ecommerce.ipynb"
if os.path.exists(notebook_name):
    # !git add "{notebook_name}"
    print(f"Added '{notebook_name}' to the staging area.")
else:
    print(f"Error: '{notebook_name}' not found in the current directory. Please ensure it was copied successfully.")
# Out:
# Added 'Ecommerce.ipynb' to the staging area.

# %%
# IMPORTANT: Replace <YOUR_GITHUB_REPOSITORY_URL> with the actual HTTPS URL of your GitHub repository
# Example: !git remote add origin https://github.com/your_username/your_repo_name.git
# If you've already added 'origin' before and got an error, you might need to remove it first:
# !git remote remove origin
# !git remote add origin https://github.com/vamshi437/ecommerce-analytics.git
# Out:
# error: remote origin already exists.

# %% [markdown]
# ### 4. Commit Your Changes
# This command saves your added notebook to your local Git repository. Feel free to change the commit message.

# %%
# !git commit -m "Initial commit of Ecommerce notebook"
# Out:
# [main 7106d4a] Initial commit of Ecommerce notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Ecommerce.ipynb (70%)

# %% [markdown]
# ### 5. Add Your GitHub Repository as a Remote
# Now you need to link your local Git repository to your GitHub repository. Go to your GitHub repository (it should be empty or initialized), copy its HTTPS URL, and replace `<YOUR_GITHUB_REPOSITORY_URL>` below with it.
#
# Example URL format: `https://github.com/your_username/your_repo_name.git`

# %%
# IMPORTANT: Replace <YOUR_GITHUB_REPOSITORY_URL> with the actual HTTPS URL of your GitHub repository
# !git remote add origin <https://github.com/vamshi437/ecommerce-analytics.git>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git remote add origin <https://github.com/vamshi437/ecommerce-analytics.git>'

# %% [markdown]
# ### 6. Push Your Changes to GitHub
# Finally, push your committed changes to your GitHub repository. You might be prompted for your GitHub username and Personal Access Token (PAT).
#
# If you don't have a PAT, you'll need to create one in your GitHub settings (`Settings` > `Developer settings` > `Personal access tokens`). When prompted for a password, use your PAT, not your GitHub account password.

# %%
# IMPORTANT: Replace YOUR_GITHUB_USERNAME and YOUR_PERSONAL_ACCESS_TOKEN with your actual GitHub credentials
# If you don't have a PAT, generate one in GitHub settings (Developer settings -> Personal access tokens)
# !git branch -M main
# !git push -u origin https://YOUR_GITHUB_USERNAME:YOUR_PERSONAL_ACCESS_TOKEN@github.com/vamshi437/ecommerce-analytics.git
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
